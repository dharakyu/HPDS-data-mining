# %%
'''
This script is a customized version of tag_reviews.ipynb and is used
to parse the vocab in a table to a list in regex format
'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# This block is only used if you are planning to access the csv file through Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# TODO: Update Path to the csv file
path = "drive/My Drive/Hybrid Physical+Digital Spaces/Studies/Data Mining/Colab/dictionaries/built-features-vocab-raw.csv"

build_features = pd.read_csv(path)
build_features

# %%
# store the final list of vocab words
lex = []

# add spaces and remove "*"
# this step works in place of Regular Expressions
for feature in build_features:
  for i in range(len(build_features[feature])):
    if f'{build_features[feature][i]}' == 'nan':
      # Skip nan's
      continue
    lex.append(" " + build_features[feature][i])
    if "*" in lex[-1]:
        lex[-1] = lex[-1].replace("*", "")
    else:
        lex[-1] = lex[-1] + " "
        
    lex[-1] = lex[-1].lower()
            
lex

import pandas as pd
df = pd.DataFrame(lex)
df.to_csv('built_features_vocab.csv')
# Out:
# [' steel ',
#  ' Steel framing',
#  ' Mezzanine ',
#  ' cladding rails ',
#  ' wires ',
#  ' mud ',
#  ' mud brick',
#  ' rammed earth ',
#  ' Concrete ',
#  ' Elevator',
#  ' Escalator',
#  ' Composite',
#  ' Thermal protection ',
#  ' insulation ',
#  ' Moisture protection ',
#  ' Building envelop',
#  ' Conformal coating ',
#  ' Housewrap',
#  ' Door',
#  ' rail',
#  ' raised panel',
#  ' wood ',
#  ' socket',
#  ' glass door',
#  ' tambour ',
#  ' Folding door',
#  ' garage door',
#  ' storefront ',
#  ' Door hardware ',
#  ' Electrical ',
#  ' plug',
#  ' Circuit breaker',
#  ' Electrical connector',
#  ' wiring',
#  ' Switch',
#  ' Surface finishing ',
#  ' Plaster ',
#  ' gypsum ',
#  ' Cement ',
#  ' Ceramic ',
#  ' quarry ',
#  ' paver',
#  ' mosaic',
#  ' ceiling',
#  ' penaling ',
#  ' carpet',
#  ' Marble ',
#  ' Wall covering ',
#  ' Wallpaper',
#  ' acoustic',
#  ' Paint',
#  ' wood stain',
#  ' faux finishing ',
#  ' extinguisher',
#  ' Stucco ',
# ...
